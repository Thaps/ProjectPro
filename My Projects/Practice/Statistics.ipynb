# %%
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt

# %%
seed(1)

# %%
data = 5 * randn(120000) + 20

# %%
plt.hist(data, bins=100)
plt.show()

# %%
randn(10000)
# Out:
# array([-1.93156389, -0.16042612, -0.83221954, ..., -0.08383815,
#        -1.28353453,  0.34231235])
